# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np

# %%
map_df = pd.read_csv("MDL_adoptive_metadata.txt", sep='\t', index_col='#SampleID')

# %%
dm_df = pd.read_csv("weighted_unifrac_dm.txt", sep='\t', index_col=0)

# %%
#stack the series and filter out the duplicates 
dm_series = dm_df.stack()
seen = []
for id_pair in dm_series.index.tolist():
    if id_pair[::-1] in seen:
        continue
    seen.append(id_pair)

dm_series = dm_series[seen]

# %%
stack_df = DataFrame(dm_series)
stack_df.columns = ['dist']

# %%
def add_metadata(compare):
    def callback(row):
        key1 = row.name[0]
        key2 = row.name[1]
        
        def lookup(key):
            return (map_df.lookup([key1], [key]),
                    map_df.lookup([key2], [key]))
        
        return compare(lookup)
        
    return callback

def bodysite(lookup):
    b1, b2 = lookup('BodySite')
    if b1 == b2:
        return b1[0]
    return 'drop'

def familynumber(lookup):
    fn1, fn2 = lookup('Family_Number')
    if fn1 == fn2:
        return fn1[0]
    return 0


def adoptstatus(lookup):
    fn1, fn2 = lookup('Family_Number')
    p1, p2 = lookup('Person')
    if fn1 == fn2:
        if p1 == p2:
            return 'self_not'
        a1, a2 = lookup('adopt_status')
        child = ['Bio', 'Afr', 'USA']
        parent = ['Mom', 'Dad']
        if a1 in child and a2 in parent:
            return 'child_%s' % a1[0]
        elif a2 in child and a1 in parent:
            return 'child_%s' % a2[0]
        
        if a1 in child and a2 in child:
            return 'sibling_not'

        if a1 in parent and a2 in parent:
            return 'spouse_not'
    return 'not_not'   
    
stack_df['Adopt_Status'] = stack_df.apply(add_metadata(adoptstatus), axis=1)
stack_df['Family_Number'] = stack_df.apply(add_metadata(familynumber), axis=1)
stack_df['Body_Site'] = stack_df.apply(add_metadata(bodysite), axis=1)

# %%
stack_df = stack_df[stack_df.dist != 0]

# %%
stack_df = stack_df[stack_df.Body_Site != 'drop']

# %%
stack_df
# Out:
#                                                dist Adopt_Status  \
# FN4Dad.Mouth.TP2     FN4Dad.Mouth.TP3      0.314122     self_not
#                      FN4Dad.Mouth.TP1      0.336239     self_not
#                      FN1Child.2.Mouth.TP3  0.570471      not_not
#                      FN6Dad.Mouth.TP1      0.286093      not_not
#                      FN6Dad.Mouth.TP2      0.205140      not_not
#                      FN6Dad.Mouth.TP3      0.208061      not_not
#                      FN1Mom.Mouth.TP3      0.444215      not_not
#                      FN8Dad.Mouth.TP3      0.789817      not_not
#                      FN1Child.2.Mouth.TP1  0.703049      not_not
#                      FN9Child.1.Mouth.TP3  0.544469      not_not
#                      FN9Child.1.Mouth.TP2  0.401080      not_not
#                      FN9Child.1.Mouth.TP1  0.512538      not_not
#                      FN1Child.1.Mouth.TP3  0.428180      not_not
#                      FN1Child.1.Mouth.TP1  0.667883      not_not
#                      FN8Dad.Mouth.TP2      0.551160      not_not
#                      FN1Mom.Mouth.TP2      0.589615      not_not
#                      FN1Mom.Mouth.TP1      0.353024      not_not
#                      FN8Dad.Mouth.TP1      0.383148      not_not
#                      FN6Child.2.Mouth.TP3  0.465781      not_not
#                      FN6Child.2.Mouth.TP2  0.359860      not_not
#                      FN1Child.2.Mouth.TP2  0.750703      not_not
#                      FN6Child.1.Mouth.TP2  0.504480      not_not
#                      FN6Child.1.Mouth.TP3  0.247846      not_not
#                      FN6Child.1.Mouth.TP1  0.403542      not_not
#                      FN8Child.1.Mouth.TP1  0.493086      not_not
#                      FN8Child.1.Mouth.TP3  0.511999      not_not
#                      FN8Mom.Mouth.TP1      0.508532      not_not
#                      FN4Mom.Mouth.TP1      0.421447   spouse_not
#                      FN6Child.1.Mouth.TP1              0     Mouth
#                      FN8Child.1.Mouth.TP1              0     Mouth
#                      FN8Child.1.Mouth.TP3              0     Mouth
#                      FN8Mom.Mouth.TP1                  0     Mouth
#                      FN4Mom.Mouth.TP1                  4     Mouth
#                      FN4Mom.Mouth.TP2                  4     Mouth
#                      FN4Mom.Mouth.TP3                  4     Mouth
# ...                                                  ...       ...
# FN1Dad.Mouth.TP3     FN7Dad.Mouth.TP2                  0     Mouth
#                      FN7Dad.Mouth.TP1                  0     Mouth
# FN1Dad.Mouth.TP2     FN7Dad.Mouth.TP3                  0     Mouth
#                      FN7Dad.Mouth.TP2                  0     Mouth
#                      FN7Dad.Mouth.TP1                  0     Mouth
# FN1Child.1.Nasal.TP3 FN1Child.1.Nasal.TP2              1     Nasal
#                      FN1Child.1.Nasal.TP1              1     Nasal
#                      FN6Child.2.Nasal.TP1              0     Nasal
#                      FN6Child.2.Nasal.TP3              0     Nasal
#                      FN6Child.2.Nasal.TP2              0     Nasal
#                      FN9Child.2.Nasal.TP2              0     Nasal
# FN1Child.1.Nasal.TP2 FN1Child.1.Nasal.TP1              1     Nasal
#                      FN6Child.2.Nasal.TP1              0     Nasal
#                      FN6Child.2.Nasal.TP3              0     Nasal
#                      FN6Child.2.Nasal.TP2              0     Nasal
#                      FN9Child.2.Nasal.TP2              0     Nasal
# FN1Child.1.Nasal.TP1 FN6Child.2.Nasal.TP1              0     Nasal
#                      FN6Child.2.Nasal.TP3              0     Nasal
#                      FN6Child.2.Nasal.TP2              0     Nasal
#                      FN9Child.2.Nasal.TP2              0     Nasal
# FN6Child.2.Nasal.TP1 FN6Child.2.Nasal.TP3              6     Nasal
#                      FN6Child.2.Nasal.TP2              6     Nasal
#                      FN9Child.2.Nasal.TP2              0     Nasal
# FN6Child.2.Nasal.TP3 FN6Child.2.Nasal.TP2              6     Nasal
#                      FN9Child.2.Nasal.TP2              0     Nasal
# FN6Child.2.Nasal.TP2 FN9Child.2.Nasal.TP2              0     Nasal
# FN9Child.1.Stool.TP1 FN6Child.2.Stool.TP2              0     Stool
# FN7Dad.Mouth.TP3     FN7Dad.Mouth.TP2                  7     Mouth
#                      FN7Dad.Mouth.TP1                  7     Mouth
# FN7Dad.Mouth.TP2     FN7Dad.Mouth.TP1                  7     Mouth
#
# [10543 rows x 4 columns]

# %%
#stack_df['Relationship'] = 'NaN'

# %%
#stack_df

# %%
#stack_df.head()

# %%
#stack_df.Relationship.unique()

# %%
#stack_df

# %%
stack_df.to_csv('weighted_filtered_bodysite_table.txt')

# %%
#stack_df.head()

# %%
#stack_df[stack_df['Adopt_Status'] != 'no']

# %%
#erson_df = pd.read_csv("filtered_stool_table_person.csv", sep=',', index_col = ['Person1','Person2'])

# %%
#person_df.head()

# %%
#stack_df.head()

# %%
# for i, row in stack_df.iterrows():
#     print i[0]
#     for j, p_row in person_df.iterrows():
#         print j
#         if i[0] == j[0] and i[0] == j[1] and i[1] == j[1]:
#             stack_df.ix[i, 'Person_Number_'] = person_df.ix[j, 'Person']

# %% [markdown]
# To do
# -----
# 1. Remove duplicates
# 2. Remove 0s
# 3. Potentially be able to add metadata fo second sample ID
# 4. Convert categorical data into integers?
#
# Questions
# ---------
# 1. Does the metada for both IDs need to be present?
# 2. Can we do this with beta diversity metrics. This statistic *only* exists as paired data. Why does this work? (It probably won't) - John
# 3.

# %% [markdown]
# Here I want to be able to combine these two data frames. I think that the best way to do this is going to be with the apply function, however there may be a way to do this with merge, join or concat. can't figure it out though.
