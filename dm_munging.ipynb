# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np

# %%
map_df = pd.read_csv("MDL_adoptive_metadata.txt", sep='\t', index_col='#SampleID')
map_df[:5]
# Out:
#                      BarcodeSequence              LinkerPrimerSequence  \
# #SampleID
# Calf.Thymus.NC1         TGCAAGCTAAGT  AGTCAGTCAGCCGGACTACHVGGGTWTCTAAT
# Calf.Thymus.NC2         TACCTGTGTCTT  AGTCAGTCAGCCGGACTACHVGGGTWTCTAAT
# FN1Child.1.Mouth.TP1    ATAGGCTGTAGT  AGTCAGTCAGCCGGACTACHVGGGTWTCTAAT
# FN1Child.1.Mouth.TP3    AGGCACAGTAGG  AGTCAGTCAGCCGGACTACHVGGGTWTCTAAT
# FN1Child.1.Nasal.TP1    GTGTCCGGATTC  AGTCAGTCAGCCGGACTACHVGGGTWTCTAAT
#
#                      Date_Started  Family_Number Person   Birthdate Stool  \
# #SampleID
# Calf.Thymus.NC1               NaN            NaN    NaN         NaN   NaN
# Calf.Thymus.NC2               NaN            NaN    NaN         NaN   NaN
# FN1Child.1.Mouth.TP1    8_14_2013              1    1c1  11_14_1995    No
# FN1Child.1.Mouth.TP3    8_14_2013              1    1c1  11_14_1995    No
# FN1Child.1.Nasal.TP1    8_14_2013              1    1c1  11_14_1995    No
#
#                      Nasal Mouth    BodySite     ...     appendix_removed  \
# #SampleID                                        ...
# Calf.Thymus.NC1        NaN   NaN  CalfThymus     ...                  NaN
# Calf.Thymus.NC2        NaN   NaN  CalfThymus     ...                  NaN
# FN1Child.1.Mouth.TP1    No   Yes       Mouth     ...                   No
# FN1Child.1.Mouth.TP3    No   Yes       Mouth     ...                   No
# FN1Child.1.Nasal.TP1   Yes    No       Nasal     ...                   No
#
#                       chickenpox  \
# #SampleID
# Calf.Thymus.NC1              NaN
# Calf.Thymus.NC2              NaN
# FN1Child.1.Mouth.TP1         Yes
# FN1Child.1.Mouth.TP3         Yes
# FN1Child.1.Nasal.TP1         Yes
#
#                      Do_you_currently_take_any_over_the_counter_or_prescription_medication  \
# #SampleID
# Calf.Thymus.NC1                                                     NaN
# Calf.Thymus.NC2                                                     NaN
# FN1Child.1.Mouth.TP1                                               None
# FN1Child.1.Mouth.TP3                                               None
# FN1Child.1.Nasal.TP1                                               None
#
#                      seasonal_allergies  non_food_allergies  \
# #SampleID
# Calf.Thymus.NC1                     NaN                 NaN
# Calf.Thymus.NC2                     NaN                 NaN
# FN1Child.1.Mouth.TP1                 No             Nothing
# FN1Child.1.Mouth.TP3                 No             Nothing
# FN1Child.1.Nasal.TP1                 No             Nothing
#
#                       Is_there_anything_else__in_your_daily_routine__that_you_think_may_have_an_affect_on_your_microbiome  \
# #SampleID
# Calf.Thymus.NC1                                                     NaN
# Calf.Thymus.NC2                                                     NaN
# FN1Child.1.Mouth.TP1                                               None
# FN1Child.1.Mouth.TP3                                               None
# FN1Child.1.Nasal.TP1                                               None
#
#                      Followup_survey  \
# #SampleID
# Calf.Thymus.NC1                  NaN
# Calf.Thymus.NC2                  NaN
# FN7Dad.Mouth.TP1 FN4Child.2.Mouth.TP3  0.685457    NaN
#                  FN4Child.2.Mouth.TP2  0.557697    NaN
#                  FN4Child.2.Mouth.TP1  0.411301    NaN
#                  FN3Child.2.Nasal.TP1  0.777575    NaN
#                  FN9Child.2.Nasal.TP1  0.824824    NaN
#                  FN1Mom.Stool.TP3      0.676011    NaN
#                  FN1Child.1.Stool.TP3  0.651204    NaN
#                  FN1Child.1.Stool.TP2  0.684966    NaN
#                  FN1Child.1.Stool.TP1  0.685763    NaN
#                  FN9Child.1.Nasal.TP2  0.689091    NaN
#                  FN3Child.2.Mouth.TP2  0.478677    NaN
#                  FN3Mom.Mouth.TP1      0.629944    NaN
#                  FN9Child.1.Nasal.TP1  0.724683    NaN
#                  FN3Mom.Mouth.TP3      0.627982    NaN
#                  FN3Mom.Mouth.TP2      0.655226    NaN
#                  FN1Dad.Mouth.TP1      0.292507    NaN
#                  FN1Dad.Mouth.TP3      0.214431    NaN
#                  FN1Dad.Mouth.TP2      0.218329    NaN
#                  FN1Child.1.Nasal.TP3  0.575197    NaN
#                  FN1Child.1.Nasal.TP2  0.614028    NaN
#                  FN1Child.1.Nasal.TP1  0.659736    NaN
#                  FN6Child.2.Nasal.TP1  0.768364    NaN
#                  FN6Child.2.Nasal.TP3  0.706582    NaN
#                  FN6Child.2.Nasal.TP2  0.756455    NaN
#                  FN9Child.1.Stool.TP1  0.667152    NaN
#                  FN9Child.2.Nasal.TP2  0.710723    NaN
#                  FN6Child.2.Stool.TP2  0.708750    NaN
#                  FN7Dad.Mouth.TP3      0.244596    NaN
#                  FN7Dad.Mouth.TP2      0.513578    NaN
#                  FN7Dad.Mouth.TP1      0.000000    NaN
#
# [64009 rows x 2 columns]

# %%
for col in map_df.columns:
    stack_df[col] = np.nan
    for i in stack_df.index:
        stack_df[col][i[0]] = map_df[col][i[0]]

# %%
lookup = {}
bool_list = []

def check_duplicate(x):
    keya = x.name[0]
    keyb = x.name[1]
    
    def check_a():
        if keya in lookup:
            if keyb in lookup[keya]:
                return False
            else:
                return check_b()
        else:
            return check_b()
        
    def check_b():
        if keyb in lookup:
            if keya in lookup[keyb]:
                return False
            else:
                return add()
        else:
            return add()
    
    def add():
        if keya not in lookup:
            lookup[keya] = {}
        lookup[keya][keyb] = True
        return True
        
    
    bool_list.append(check_a())
    
stack_df.apply(check_duplicate, axis=1)
non_duplicated = pd.Series(bool_list)
stack_df[bool_]
# Out:
# 64009
# 64009

# %%
stack_df.to_csv('stack_df.txt', '\t')

# %% [markdown]
# To do
# -----
# 1. Remove duplicates
# 2. Remove 0s
# 3. Potentially be able to add metadata fo second sample ID
# 4. Convert categorical data into integers?
#
# Questions
# ---------
# 1. Does the metada for both IDs need to be present?
# 2. Can we do this with beta diversity metrics. This statistic *only* exists as paired data. Why does this work? (It probably won't) - John
# 3.

# %% [markdown]
# Here I want to be able to combine these two data frames. I think that the best way to do this is going to be with the apply function, however there may be a way to do this with merge, join or concat. can't figure it out though.
