# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np

# %%
map_df = pd.read_csv("MDL_adoptive_metadata.txt", sep='\t', index_col='#SampleID')

# %%
dm_df = pd.read_csv("weighted_unifrac_dm.txt", sep='\t', index_col=0)

# %%
#stack the series and filter out the duplicates 
dm_series = dm_df.stack()
seen = []
for id_pair in dm_series.index.tolist():
    if id_pair[::-1] in seen:
        continue
    seen.append(id_pair)

dm_series = dm_series[seen]

# %%
stack_df = DataFrame(dm_series)
stack_df.columns = ['dist']

# %%
def add_metadata(compare):
    def callback(row):
        key1 = row.name[0]
        key2 = row.name[1]
        
        def lookup(key):
            return (map_df.lookup([key1], [key]),
                    map_df.lookup([key2], [key]))
        
        return compare(lookup)
        
    return callback

def identity(key):
    def _(lookup):
        v1, v2 = lookup(key)
        if v1 == v2:
            return 'yes'
        return 'no'
    return _


def adopt(lookup):
    h1, h2 = lookup('Family_Number')
    if h1 == h2:
        p1, p2 = lookup('Person')
        if p1 != p2:
            a1, a2 = lookup('adopt_status')
            adopted = ['Afr', 'USA']
            not_adopted = ['Mom', 'Dad']
            if a1 in adopted and a2 in not_adopted:
                return 'adopted_' + a1[0] #Why are these arrays again??
            elif a2 in adopted and a1 in not_adopted:
                return 'adopted_' + a2[0]
    return 'no'

def sibling(lookup):
    h1, h2 = lookup('Family_Number')
    if h1 == h2:
        p1, p2 = lookup('Person')
        if p1 != p2:
            a1, a2 = lookup('adopt_status')
            sibling = ['Bio', 'Afr', 'USA']
            if a1 in sibling and a2 in sibling:
                return 'yes'
    return 'no'


def child(lookup):
    h1, h2 = lookup('Family_Number')
    if h1 == h2:
        p1, p2 = lookup('Person')
        if p1 != p2:
            a1, a2 = lookup('adopt_status')
            child = ['Bio', 'Afr', 'USA']
            parent = ['Mom', 'Dad']
            if a1 in child and a2 in parent:
                return 'yes'
            elif a2 in child and a1 in parent:
                return 'yes'
    return 'no'

def timepoint(index):
    def callback(lookup):
        timepoints = lookup('Time_Point')
        return timepoints[index][0] # Why are there arrays here???
    return callback

stack_df['Adopt_Status'] = stack_df.apply(add_metadata(adopt), axis=1)
stack_df['Family'] = stack_df.apply(add_metadata(identity('Family_Number')), axis=1)
stack_df['Person'] = stack_df.apply(add_metadata(identity('Person')), axis=1)
stack_df['Sibling'] = stack_df.apply(add_metadata(sibling), axis=1)
stack_df['Child'] = stack_df.apply(add_metadata(child), axis=1)
stack_df['TPA'] = stack_df.apply(add_metadata(timepoint(0)), axis=1)
stack_df['TPB'] = stack_df.apply(add_metadata(timepoint(1)), axis=1)

# %%
stack_df = stack_df[stack_df.dist != 0]
stack_df
# Out:
#                                                dist Adopt_Status Family  \
# FN4Dad.Mouth.TP2     FN4Dad.Mouth.TP3      0.314122           no    yes
#                      FN4Dad.Mouth.TP1      0.336239           no    yes
#                      FN8Dad.Nasal.TP2      0.762721           no     no
#                      FN8Dad.Nasal.TP3      0.648425           no     no
#                      FN8Dad.Nasal.TP1      0.820690           no     no
#                      FN7Child.3.Stool.TP3  0.821582           no     no
#                      FN7Child.3.Stool.TP2  0.757324           no     no
#                      FN7Child.3.Stool.TP1  0.757895           no     no
#                      FN1Child.2.Mouth.TP3  0.570471           no     no
#                      FN6Dad.Mouth.TP1      0.286093           no     no
#                      FN6Dad.Mouth.TP2      0.205140           no     no
#                      FN6Dad.Mouth.TP3      0.208061           no     no
#                      FN6Child.3.nasal.TP1  0.654997           no     no
#                      FN6Child.3.nasal.TP2  0.738669           no     no
#                      FN3Mom.Nasal.T2       0.661118           no     no
#                      FN1Mom.Mouth.TP3      0.444215           no     no
#                      FN8Child.1.Nasal.TP2  0.528264           no     no
#                      FN8Dad.Mouth.TP3      0.789817           no     no
#                      FN8Child.1.Nasal.TP3  0.719277           no     no
#                      FN1Child.2.Mouth.TP1  0.703049           no     no
#                      FN8Mom.Nasal.TP1      0.813796           no     no
#                      FN3Mom.Nasal.TP3      0.666133           no     no
#                      FN8Mom.Nasal.TP3      0.854962           no     no
#                      FN9Child.1.Mouth.TP3  0.544469           no     no
#                      FN9Child.1.Mouth.TP2  0.401080           no     no
#                      FN9Child.1.Mouth.TP1  0.512538           no     no
#                      FN4Dad.Nasal.TP2      0.826069           no    yes
#                      FN4Dad.Nasal.TP3      0.596023           no    yes
#                      FN4Dad.Nasal.TP1      0.517576           no    yes
#                      FN1Child.2.Nasal.TP2  0.659635           no     no
# ...                                             ...          ...    ...
# FN6Child.2.Nasal.TP1 FN7Dad.Mouth.TP2      0.554391           no     no
#                      FN7Dad.Mouth.TP1      0.768364           no     no
# FN6Child.2.Nasal.TP3 FN6Child.2.Nasal.TP2  0.537077           no    yes
#                      FN9Child.1.Stool.TP1  0.827523           no     no
#                      FN9Child.2.Nasal.TP2  0.348061           no     no
#                      FN6Child.2.Stool.TP2  0.919074           no    yes
#                      FN7Dad.Mouth.TP3      0.579621           no     no
#                      FN7Dad.Mouth.TP2      0.349336           no     no
#                      FN7Dad.Mouth.TP1      0.706582           no     no
# FN6Child.2.Nasal.TP2 FN9Child.1.Stool.TP1  0.791440           no     no
#                      FN9Child.2.Nasal.TP2  0.450693           no     no
#                      FN6Child.2.Stool.TP2  0.926015           no    yes
#                      FN7Dad.Mouth.TP3      0.771602           no     no
#                      FN7Dad.Mouth.TP2      0.677197           no     no
#                      FN7Dad.Mouth.TP1      0.756455           no     no
# FN9Child.1.Stool.TP1 FN9Child.2.Nasal.TP2  0.818389           no    yes
#                      FN6Child.2.Stool.TP2  0.496134           no     no
#                      FN7Dad.Mouth.TP3      0.671444           no     no
#                      FN7Dad.Mouth.TP2      0.831255           no     no
#                      FN7Dad.Mouth.TP1      0.667152           no     no
# FN9Child.2.Nasal.TP2 FN6Child.2.Stool.TP2  0.934217           no     no
#                      FN7Dad.Mouth.TP3      0.713248           no     no
#                      FN7Dad.Mouth.TP2      0.520316           no     no
#                      FN7Dad.Mouth.TP1      0.710723           no     no
# FN6Child.2.Stool.TP2 FN7Dad.Mouth.TP3      0.691570           no     no
#                      FN7Dad.Mouth.TP2      0.891752           no     no
#                      FN7Dad.Mouth.TP1      0.708750           no     no
# FN7Dad.Mouth.TP3     FN7Dad.Mouth.TP2      0.413509           no    yes
#                      FN7Dad.Mouth.TP1      0.244596           no    yes
# FN7Dad.Mouth.TP2     FN7Dad.Mouth.TP1      0.513578           no    yes
#
#                                           Person Sibling Child  TPA  TPB
# FN4Dad.Mouth.TP2     FN4Dad.Mouth.TP3        yes      no    no    2    3
#                      FN4Dad.Mouth.TP1        yes      no    no    2    1
#                      FN8Dad.Nasal.TP2         no      no    no    2    2
#                      FN8Dad.Nasal.TP3         no      no    no    2    3
#                      FN8Dad.Nasal.TP1         no      no    no    2    1
#                      FN7Child.3.Stool.TP3     no      no    no    2    3
#                      FN7Child.3.Stool.TP2     no      no    no    2    2
#                      FN7Child.3.Stool.TP1     no      no    no    2    1
#                      FN1Child.2.Mouth.TP3     no      no    no    2    3
#                      FN6Dad.Mouth.TP1         no      no    no    2    1
#                      FN6Dad.Mouth.TP2         no      no    no    2    2
#                      FN6Dad.Mouth.TP3         no      no    no    2    3
#                      FN6Child.3.nasal.TP1     no      no    no    2    1
#                      FN6Child.3.nasal.TP2     no      no    no    2    2
#                      FN3Mom.Nasal.T2          no      no    no    2    2
#                      FN1Mom.Mouth.TP3         no      no    no    2    3
#                      FN8Child.1.Nasal.TP2     no      no    no    2    2
#                      FN8Dad.Mouth.TP3         no      no    no    2    3
#                      FN8Child.1.Nasal.TP3     no      no    no    2    3
#                      FN1Child.2.Mouth.TP1     no      no    no    2    1
#                      FN8Mom.Nasal.TP1         no      no    no    2    1
#                      FN3Mom.Nasal.TP3         no      no    no    2    3
#                      FN8Mom.Nasal.TP3         no      no    no    2    3
#                      FN9Child.1.Mouth.TP3     no      no    no    2    3
#                      FN9Child.1.Mouth.TP2     no      no    no    2    2
#                      FN9Child.1.Mouth.TP1     no      no    no    2    1
#                      FN4Dad.Nasal.TP2        yes      no    no    2    2
#                      FN4Dad.Nasal.TP3        yes      no    no    2    3
#                      FN4Dad.Nasal.TP1        yes      no    no    2    1
#                      FN1Child.2.Nasal.TP2     no      no    no    2    2
# ...                                          ...     ...   ...  ...  ...
# FN6Child.2.Nasal.TP1 FN7Dad.Mouth.TP2         no      no    no    1    2
#                      FN7Dad.Mouth.TP1         no      no    no    1    1
# FN6Child.2.Nasal.TP3 FN6Child.2.Nasal.TP2    yes      no    no    3    2
#                      FN9Child.1.Stool.TP1     no      no    no    3    1
#                      FN9Child.2.Nasal.TP2     no      no    no    3    2
#                      FN6Child.2.Stool.TP2    yes      no    no    3    2
#                      FN7Dad.Mouth.TP3         no      no    no    3    3
#                      FN7Dad.Mouth.TP2         no      no    no    3    2
#                      FN7Dad.Mouth.TP1         no      no    no    3    1
# FN6Child.2.Nasal.TP2 FN9Child.1.Stool.TP1     no      no    no    2    1
#                      FN9Child.2.Nasal.TP2     no      no    no    2    2
#                      FN6Child.2.Stool.TP2    yes      no    no    2    2
#                      FN7Dad.Mouth.TP3         no      no    no    2    3
#                      FN7Dad.Mouth.TP2         no      no    no    2    2
#                      FN7Dad.Mouth.TP1         no      no    no    2    1
# FN9Child.1.Stool.TP1 FN9Child.2.Nasal.TP2     no     yes    no    1    2
#                      FN6Child.2.Stool.TP2     no      no    no    1    2
#                      FN7Dad.Mouth.TP3         no      no    no    1    3
#                      FN7Dad.Mouth.TP2         no      no    no    1    2
#                      FN7Dad.Mouth.TP1         no      no    no    1    1
# FN9Child.2.Nasal.TP2 FN6Child.2.Stool.TP2     no      no    no    2    2
#                      FN7Dad.Mouth.TP3         no      no    no    2    3
#                      FN7Dad.Mouth.TP2         no      no    no    2    2
#                      FN7Dad.Mouth.TP1         no      no    no    2    1
# FN6Child.2.Stool.TP2 FN7Dad.Mouth.TP3         no      no    no    2    3
#                      FN7Dad.Mouth.TP2         no      no    no    2    2
#                      FN7Dad.Mouth.TP1         no      no    no    2    1
# FN7Dad.Mouth.TP3     FN7Dad.Mouth.TP2        yes      no    no    3    2
#                      FN7Dad.Mouth.TP1        yes      no    no    3    1
# FN7Dad.Mouth.TP2     FN7Dad.Mouth.TP1        yes      no    no    2    1
#
# [31878 rows x 8 columns]

# %%
stack_df.to_csv('filtered_table.txt', sep='\t')

# %%
stack_df[stack_df['Adopt_Status'] != 'no']
# Out:
#                                                dist Adopt_Status Family  \
# FN4Dad.Mouth.TP2     FN4Child.1.Nasal.TP1  0.752656  adopted_USA    yes
#                      FN4Child.1.Stool.TP3  0.776544  adopted_USA    yes
#                      FN4Child.1.Mouth.TP1  0.488994  adopted_USA    yes
#                      FN4Child.1.Mouth.TP2  0.405187  adopted_USA    yes
#                      FN4Child.1.Mouth.TP3  0.421640  adopted_USA    yes
#                      FN4Child.2.Nasal.TP3  0.647766  adopted_USA    yes
#                      FN4Child.2.Nasal.TP2  0.679020  adopted_USA    yes
#                      FN4Child.2.Nasal.TP1  0.629672  adopted_USA    yes
#                      FN4Child.1.Stool.TP1  0.783382  adopted_USA    yes
#                      FN4Child.1.Stool.TP2  0.888244  adopted_USA    yes
#                      FN4Child.2.Stool.TP3  0.658945  adopted_USA    yes
#                      FN4Child.2.Stool.TP2  0.715825  adopted_USA    yes
#                      FN4Child.2.Stool.TP1  0.717131  adopted_USA    yes
#                      FN4Child.1.Nasal.TP2  0.698233  adopted_USA    yes
#                      FN4Child.1.Nasal.TP3  0.783448  adopted_USA    yes
#                      FN4Child.2.Mouth.TP3  0.395019  adopted_USA    yes
#                      FN4Child.2.Mouth.TP2  0.334476  adopted_USA    yes
#                      FN4Child.2.Mouth.TP1  0.422278  adopted_USA    yes
# FN4Dad.Mouth.TP3     FN4Child.1.Nasal.TP1  0.637742  adopted_USA    yes
#                      FN4Child.1.Stool.TP3  0.848941  adopted_USA    yes
#                      FN4Child.1.Mouth.TP1  0.499447  adopted_USA    yes
#                      FN4Child.1.Mouth.TP2  0.407766  adopted_USA    yes
#                      FN4Child.1.Mouth.TP3  0.338422  adopted_USA    yes
#                      FN4Child.2.Nasal.TP3  0.526541  adopted_USA    yes
#                      FN4Child.2.Nasal.TP2  0.587624  adopted_USA    yes
#                      FN4Child.2.Nasal.TP1  0.495959  adopted_USA    yes
#                      FN4Child.1.Stool.TP1  0.864954  adopted_USA    yes
#                      FN4Child.1.Stool.TP2  0.797454  adopted_USA    yes
#                      FN4Child.2.Stool.TP3  0.775268  adopted_USA    yes
#                      FN4Child.2.Stool.TP2  0.775518  adopted_USA    yes
# ...                                             ...          ...    ...
# FN9Dad.Stool.TP3     FN9Child.2.Nasal.TP1  0.848551  adopted_Afr    yes
#                      FN9Child.2.Nasal.TP2  0.796001  adopted_Afr    yes
# FN9Dad.Stool.TP2     FN9Child.2.Nasal.TP1  0.831333  adopted_Afr    yes
#                      FN9Child.2.Nasal.TP2  0.776866  adopted_Afr    yes
# FN9Mom.Nasal.TP3     FN9Child.2.Nasal.TP1  0.633517  adopted_Afr    yes
#                      FN9Child.2.Nasal.TP2  0.569470  adopted_Afr    yes
# FN1Mom.Stool.TP3     FN1Child.1.Stool.TP3  0.740249  adopted_Afr    yes
#                      FN1Child.1.Stool.TP2  0.283758  adopted_Afr    yes
#                      FN1Child.1.Stool.TP1  0.316262  adopted_Afr    yes
#                      FN1Child.1.Nasal.TP3  0.768234  adopted_Afr    yes
#                      FN1Child.1.Nasal.TP2  0.792218  adopted_Afr    yes
#                      FN1Child.1.Nasal.TP1  0.817536  adopted_Afr    yes
# FN1Child.1.Stool.TP3 FN1Dad.Mouth.TP1      0.680700  adopted_Afr    yes
#                      FN1Dad.Mouth.TP3      0.686797  adopted_Afr    yes
#                      FN1Dad.Mouth.TP2      0.684123  adopted_Afr    yes
# FN1Child.1.Stool.TP2 FN1Dad.Mouth.TP1      0.647603  adopted_Afr    yes
#                      FN1Dad.Mouth.TP3      0.593294  adopted_Afr    yes
#                      FN1Dad.Mouth.TP2      0.672259  adopted_Afr    yes
# FN1Child.1.Stool.TP1 FN1Dad.Mouth.TP1      0.650746  adopted_Afr    yes
#                      FN1Dad.Mouth.TP3      0.594575  adopted_Afr    yes
#                      FN1Dad.Mouth.TP2      0.674810  adopted_Afr    yes
# FN1Dad.Mouth.TP1     FN1Child.1.Nasal.TP3  0.684825  adopted_Afr    yes
#                      FN1Child.1.Nasal.TP2  0.690333  adopted_Afr    yes
#                      FN1Child.1.Nasal.TP1  0.763289  adopted_Afr    yes
# FN1Dad.Mouth.TP3     FN1Child.1.Nasal.TP3  0.643523  adopted_Afr    yes
#                      FN1Child.1.Nasal.TP2  0.667123  adopted_Afr    yes
#                      FN1Child.1.Nasal.TP1  0.729290  adopted_Afr    yes
# FN1Dad.Mouth.TP2     FN1Child.1.Nasal.TP3  0.665532  adopted_Afr    yes
#                      FN1Child.1.Nasal.TP2  0.674970  adopted_Afr    yes
#                      FN1Child.1.Nasal.TP1  0.746412  adopted_Afr    yes
#
#                                           Person Sibling Child  TPA  TPB
# FN4Dad.Mouth.TP2     FN4Child.1.Nasal.TP1     no      no   yes    2    1
#                      FN4Child.1.Stool.TP3     no      no   yes    2    3
#                      FN4Child.1.Mouth.TP1     no      no   yes    2    1
#                      FN4Child.1.Mouth.TP2     no      no   yes    2    2
#                      FN4Child.1.Mouth.TP3     no      no   yes    2    3
#                      FN4Child.2.Nasal.TP3     no      no   yes    2    3
#                      FN4Child.2.Nasal.TP2     no      no   yes    2    2
#                      FN4Child.2.Nasal.TP1     no      no   yes    2    1
#                      FN4Child.1.Stool.TP1     no      no   yes    2    1
#                      FN4Child.1.Stool.TP2     no      no   yes    2    2
#                      FN4Child.2.Stool.TP3     no      no   yes    2    3
#                      FN4Child.2.Stool.TP2     no      no   yes    2    2
#                      FN4Child.2.Stool.TP1     no      no   yes    2    1
#                      FN4Child.1.Nasal.TP2     no      no   yes    2    2
#                      FN4Child.1.Nasal.TP3     no      no   yes    2    3
#                      FN4Child.2.Mouth.TP3     no      no   yes    2    3
#                      FN4Child.2.Mouth.TP2     no      no   yes    2    2
#                      FN4Child.2.Mouth.TP1     no      no   yes    2    1
# FN4Dad.Mouth.TP3     FN4Child.1.Nasal.TP1     no      no   yes    3    1
#                      FN4Child.1.Stool.TP3     no      no   yes    3    3
#                      FN4Child.1.Mouth.TP1     no      no   yes    3    1
#                      FN4Child.1.Mouth.TP2     no      no   yes    3    2
#                      FN4Child.1.Mouth.TP3     no      no   yes    3    3
#                      FN4Child.2.Nasal.TP3     no      no   yes    3    3
#                      FN4Child.2.Nasal.TP2     no      no   yes    3    2
#                      FN4Child.2.Nasal.TP1     no      no   yes    3    1
#                      FN4Child.1.Stool.TP1     no      no   yes    3    1
#                      FN4Child.1.Stool.TP2     no      no   yes    3    2
#                      FN4Child.2.Stool.TP3     no      no   yes    3    3
#                      FN4Child.2.Stool.TP2     no      no   yes    3    2
# ...                                          ...     ...   ...  ...  ...
# FN9Dad.Stool.TP3     FN9Child.2.Nasal.TP1     no      no   yes    3    1
#                      FN9Child.2.Nasal.TP2     no      no   yes    3    2
# FN9Dad.Stool.TP2     FN9Child.2.Nasal.TP1     no      no   yes    2    1
#                      FN9Child.2.Nasal.TP2     no      no   yes    2    2
# FN9Mom.Nasal.TP3     FN9Child.2.Nasal.TP1     no      no   yes    3    1
#                      FN9Child.2.Nasal.TP2     no      no   yes    3    2
# FN1Mom.Stool.TP3     FN1Child.1.Stool.TP3     no      no   yes    3    3
#                      FN1Child.1.Stool.TP2     no      no   yes    3    2
#                      FN1Child.1.Stool.TP1     no      no   yes    3    1
#                      FN1Child.1.Nasal.TP3     no      no   yes    3    3
#                      FN1Child.1.Nasal.TP2     no      no   yes    3    2
#                      FN1Child.1.Nasal.TP1     no      no   yes    3    1
# FN1Child.1.Stool.TP3 FN1Dad.Mouth.TP1         no      no   yes    3    1
#                      FN1Dad.Mouth.TP3         no      no   yes    3    3
#                      FN1Dad.Mouth.TP2         no      no   yes    3    2
# FN1Child.1.Stool.TP2 FN1Dad.Mouth.TP1         no      no   yes    2    1
#                      FN1Dad.Mouth.TP3         no      no   yes    2    3
#                      FN1Dad.Mouth.TP2         no      no   yes    2    2
# FN1Child.1.Stool.TP1 FN1Dad.Mouth.TP1         no      no   yes    1    1
#                      FN1Dad.Mouth.TP3         no      no   yes    1    3
#                      FN1Dad.Mouth.TP2         no      no   yes    1    2
# FN1Dad.Mouth.TP1     FN1Child.1.Nasal.TP3     no      no   yes    1    3
#                      FN1Child.1.Nasal.TP2     no      no   yes    1    2
#                      FN1Child.1.Nasal.TP1     no      no   yes    1    1
# FN1Dad.Mouth.TP3     FN1Child.1.Nasal.TP3     no      no   yes    3    3
#                      FN1Child.1.Nasal.TP2     no      no   yes    3    2
#                      FN1Child.1.Nasal.TP1     no      no   yes    3    1
# FN1Dad.Mouth.TP2     FN1Child.1.Nasal.TP3     no      no   yes    2    3
#                      FN1Child.1.Nasal.TP2     no      no   yes    2    2
#                      FN1Child.1.Nasal.TP1     no      no   yes    2    1
#
# [1531 rows x 8 columns]

# %% [markdown]
# To do
# -----
# 1. Remove duplicates
# 2. Remove 0s
# 3. Potentially be able to add metadata fo second sample ID
# 4. Convert categorical data into integers?
#
# Questions
# ---------
# 1. Does the metada for both IDs need to be present?
# 2. Can we do this with beta diversity metrics. This statistic *only* exists as paired data. Why does this work? (It probably won't) - John
# 3.

# %% [markdown]
# Here I want to be able to combine these two data frames. I think that the best way to do this is going to be with the apply function, however there may be a way to do this with merge, join or concat. can't figure it out though.

# %%
hello = 'hello'
print hello[::-1]
# Out:
# olleh
