# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np

# %%
map_df = pd.read_csv("MDL_adoptive_metadata.txt", sep='\t', index_col='#SampleID')

# %%
dm_df = pd.read_csv("weighted_unifrac_dm.txt", sep='\t', index_col=0)

# %%
#stack the series and filter out the duplicates 
dm_series = dm_df.stack()
seen = []
for id_pair in dm_series.index.tolist():
    if id_pair[::-1] in seen:
        continue
    seen.append(id_pair)

dm_series = dm_series[seen]

# %%
stack_df = DataFrame(dm_series)
stack_df.columns = ['dist']

# %%
def add_metadata(compare):
    def callback(row):
        key1 = row.name[0]
        key2 = row.name[1]
        
        def lookup(key):
            return (map_df.lookup([key1], [key]),
                    map_df.lookup([key2], [key]))
        
        return compare(lookup)
        
    return callback

def identity(key):
    def _(lookup):
        v1, v2 = lookup(key)
        if v1 == v2:
            return 'yes'
        return 'no'
    return _


def adopt(lookup):
    h1, h2 = lookup('Family_Number')
    if h1 == h2:
        p1, p2 = lookup('Person')
        if p1 != p2:
            a1, a2 = lookup('adopt_status')
            adopted = ['Afr', 'USA']
            not_adopted = ['Mom', 'Dad']
            if a1 in adopted and a2 in not_adopted:
                return 'adopted_' + a1[0] #Why are these arrays again??
            elif a2 in adopted and a1 in not_adopted:
                return 'adopted_' + a2[0]
    return 'no'

def sibling(lookup):
    h1, h2 = lookup('Family_Number')
    if h1 == h2:
        p1, p2 = lookup('Person')
        if p1 != p2:
            a1, a2 = lookup('adopt_status')
            sibling = ['Bio', 'Afr', 'USA']
            if a1 in sibling and a2 in sibling:
                return 'yes'
    return 'no'


def child(lookup):
    h1, h2 = lookup('Family_Number')
    if h1 == h2:
        p1, p2 = lookup('Person')
        if p1 != p2:
            a1, a2 = lookup('adopt_status')
            child = ['Bio', 'Afr', 'USA']
            parent = ['Mom', 'Dad']
            if a1 in child and a2 in parent:
                return 'yes'
            elif a2 in child and a1 in parent:
                return 'yes'
    return 'no'

def bodysite(lookup):
    b1, b2 = lookup('BodySite')
    if b1 == b2:
        return b1[0]
    return 'drop'

stack_df['Adopt_Status'] = stack_df.apply(add_metadata(adopt), axis=1)
stack_df['Family'] = stack_df.apply(add_metadata(identity('Family_Number')), axis=1)
stack_df['Body_Site'] = stack_df.apply(add_metadata(bodysite), axis=1)

stack_df['Person'] = stack_df.apply(add_metadata(identity('Person')), axis=1)
stack_df['Sibling'] = stack_df.apply(add_metadata(sibling), axis=1)
stack_df['Child'] = stack_df.apply(add_metadata(child), axis=1)
# Out:
# 32131
# 32131
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-b5f6ff03dff5> in <module>()
#      72 print len(series)
#      73 print len(stack_df)
# ---> 74 stack_df['Body_Site'] = series
#      75 stack_df['Person'] = stack_df.apply(add_metadata(identity('Person')), axis=1)
#      76 stack_df['Sibling'] = stack_df.apply(add_metadata(sibling), axis=1)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2005         else:
#    2006             # set column
# -> 2007             self._set_item(key, value)
#    2008
#    2009     def _setitem_slice(self, key, value):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    2084         self._ensure_valid_index(value)
#    2085         value = self._sanitize_column(key, value)
# -> 2086         NDFrame._set_item(self, key, value)
#    2087
#    2088         # check if we are modifying a copy
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _set_item(self, key, value)
#    1137
#    1138     def _set_item(self, key, value):
# -> 1139         self._data.set(key, value)
#    1140         self._clear_item_cache()
#    1141
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in set(self, item, value, check)
#    2685         except KeyError:
#    2686             # This item wasn't present, just insert at end
# -> 2687             self.insert(len(self.items), item, value)
#    2688             return
#    2689
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in insert(self, loc, item, value, allow_duplicates)
#    2784         block = make_block(values=value,
#    2785                            ndim=self.ndim,
# -> 2786                            placement=slice(loc, loc+1))
#    2787
#    2788         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in make_block(values, placement, klass, ndim, dtype, fastpath)
#    1845
#    1846     return klass(values, ndim=ndim, fastpath=fastpath,
# -> 1847                  placement=placement)
#    1848
#    1849
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in __init__(self, values, ndim, fastpath, placement)
#    1243         super(ObjectBlock, self).__init__(values, ndim=ndim,
#    1244                                           fastpath=fastpath,
# -> 1245                                           placement=placement)
#    1246
#    1247     @property
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in __init__(self, values, placement, ndim, fastpath)
#      70             raise ValueError('Wrong number of items passed %d,'
#      71                              ' placement implies %d' % (
# ---> 72                                  len(self.values), len(self.mgr_locs)))
#      73
#      74     @property
#
# ValueError: Wrong number of items passed 3, placement implies 1

# %%
#stack_df.head()

# %%
stack_df = stack_df[stack_df.dist != 0]

# %%
stack_df = stack_df[stack_df.Body_Site != 'drop']

# %%
#stack_df['Relationship'] = 'NaN'

# %%
#stack_df
# Out:
#                                                dist Adopt_Status Family  \
# FN4Dad.Mouth.TP2     FN4Dad.Mouth.TP3      0.314122           no    yes
#                      FN4Dad.Mouth.TP1      0.336239           no    yes
#                      FN8Dad.Nasal.TP2      0.762721           no     no
#                      FN8Dad.Nasal.TP3      0.648425           no     no
#                      FN8Dad.Nasal.TP1      0.820690           no     no
#                      FN7Child.3.Stool.TP3  0.821582           no     no
#                      FN7Child.3.Stool.TP2  0.757324           no     no
#                      FN7Child.3.Stool.TP1  0.757895           no     no
#                      FN1Child.2.Mouth.TP3  0.570471           no     no
#                      FN6Dad.Mouth.TP1      0.286093           no     no
#                      FN6Dad.Mouth.TP2      0.205140           no     no
#                      FN6Dad.Mouth.TP3      0.208061           no     no
#                      FN6Child.3.nasal.TP1  0.654997           no     no
#                      FN6Child.3.nasal.TP2  0.738669           no     no
#                      FN3Mom.Nasal.T2       0.661118           no     no
#                      FN1Mom.Mouth.TP3      0.444215           no     no
#                      FN8Child.1.Nasal.TP2  0.528264           no     no
#                      FN8Dad.Mouth.TP3      0.789817           no     no
#                      FN8Child.1.Nasal.TP3  0.719277           no     no
#                      FN1Child.2.Mouth.TP1  0.703049           no     no
#                      FN8Mom.Nasal.TP1      0.813796           no     no
#                      FN3Mom.Nasal.TP3      0.666133           no     no
#                      FN8Mom.Nasal.TP3      0.854962           no     no
#                      FN9Child.1.Mouth.TP3  0.544469           no     no
#                      FN9Child.1.Mouth.TP2  0.401080           no     no
#                      FN9Child.1.Mouth.TP1  0.512538           no     no
#                      FN4Dad.Nasal.TP2      0.826069           no    yes
#                      FN4Dad.Nasal.TP3      0.596023           no    yes
#                      FN4Dad.Nasal.TP1      0.517576           no    yes
#                      FN1Child.2.Nasal.TP2  0.659635           no     no
# ...                                             ...          ...    ...
# FN6Child.2.Nasal.TP1 FN7Dad.Mouth.TP2      0.554391           no     no
#                      FN7Dad.Mouth.TP1      0.768364           no     no
# FN6Child.2.Nasal.TP3 FN6Child.2.Nasal.TP2  0.537077           no    yes
#                      FN9Child.1.Stool.TP1  0.827523           no     no
#                      FN9Child.2.Nasal.TP2  0.348061           no     no
#                      FN6Child.2.Stool.TP2  0.919074           no    yes
#                      FN7Dad.Mouth.TP3      0.579621           no     no
#                      FN7Dad.Mouth.TP2      0.349336           no     no
#                      FN7Dad.Mouth.TP1      0.706582           no     no
# FN6Child.2.Nasal.TP2 FN9Child.1.Stool.TP1  0.791440           no     no
#                      FN9Child.2.Nasal.TP2  0.450693           no     no
#                      FN6Child.2.Stool.TP2  0.926015           no    yes
#                      FN7Dad.Mouth.TP3      0.771602           no     no
#                      FN7Dad.Mouth.TP2      0.677197           no     no
#                      FN7Dad.Mouth.TP1      0.756455           no     no
# FN9Child.1.Stool.TP1 FN9Child.2.Nasal.TP2  0.818389           no    yes
#                      FN6Child.2.Stool.TP2  0.496134           no     no
#                      FN7Dad.Mouth.TP3      0.671444           no     no
#                      FN7Dad.Mouth.TP2      0.831255           no     no
#                      FN7Dad.Mouth.TP1      0.667152           no     no
# FN9Child.2.Nasal.TP2 FN6Child.2.Stool.TP2  0.934217           no     no
#                      FN7Dad.Mouth.TP3      0.713248           no     no
#                      FN7Dad.Mouth.TP2      0.520316           no     no
#                      FN7Dad.Mouth.TP1      0.710723           no     no
# FN6Child.2.Stool.TP2 FN7Dad.Mouth.TP3      0.691570           no     no
#                      FN7Dad.Mouth.TP2      0.891752           no     no
#                      FN7Dad.Mouth.TP1      0.708750           no     no
# FN7Dad.Mouth.TP3     FN7Dad.Mouth.TP2      0.413509           no    yes
#                      FN7Dad.Mouth.TP1      0.244596           no    yes
# FN7Dad.Mouth.TP2     FN7Dad.Mouth.TP1      0.513578           no    yes
#
#                                           Body_Site Person Sibling Child
# FN4Dad.Mouth.TP2     FN4Dad.Mouth.TP3           yes    yes      no    no
#                      FN4Dad.Mouth.TP1           yes    yes      no    no
#                      FN8Dad.Nasal.TP2            no     no      no    no
#                      FN8Dad.Nasal.TP3            no     no      no    no
#                      FN8Dad.Nasal.TP1            no     no      no    no
#                      FN7Child.3.Stool.TP3        no     no      no    no
#                      FN7Child.3.Stool.TP2        no     no      no    no
#                      FN7Child.3.Stool.TP1        no     no      no    no
#                      FN1Child.2.Mouth.TP3       yes     no      no    no
#                      FN6Dad.Mouth.TP1           yes     no      no    no
#                      FN6Dad.Mouth.TP2           yes     no      no    no
#                      FN6Dad.Mouth.TP3           yes     no      no    no
#                      FN6Child.3.nasal.TP1        no     no      no    no
#                      FN6Child.3.nasal.TP2        no     no      no    no
#                      FN3Mom.Nasal.T2             no     no      no    no
#                      FN1Mom.Mouth.TP3           yes     no      no    no
#                      FN8Child.1.Nasal.TP2        no     no      no    no
#                      FN8Dad.Mouth.TP3           yes     no      no    no
#                      FN8Child.1.Nasal.TP3        no     no      no    no
#                      FN1Child.2.Mouth.TP1       yes     no      no    no
#                      FN8Mom.Nasal.TP1            no     no      no    no
#                      FN3Mom.Nasal.TP3            no     no      no    no
#                      FN8Mom.Nasal.TP3            no     no      no    no
#                      FN9Child.1.Mouth.TP3       yes     no      no    no
#                      FN9Child.1.Mouth.TP2       yes     no      no    no
#                      FN9Child.1.Mouth.TP1       yes     no      no    no
#                      FN4Dad.Nasal.TP2            no    yes      no    no
#                      FN4Dad.Nasal.TP3            no    yes      no    no
#                      FN4Dad.Nasal.TP1            no    yes      no    no
#                      FN1Child.2.Nasal.TP2        no     no      no    no
# ...                                             ...    ...     ...   ...
# FN6Child.2.Nasal.TP1 FN7Dad.Mouth.TP2            no     no      no    no
#                      FN7Dad.Mouth.TP1            no     no      no    no
# FN6Child.2.Nasal.TP3 FN6Child.2.Nasal.TP2       yes    yes      no    no
#                      FN9Child.1.Stool.TP1        no     no      no    no
#                      FN9Child.2.Nasal.TP2       yes     no      no    no
#                      FN6Child.2.Stool.TP2        no    yes      no    no
#                      FN7Dad.Mouth.TP3            no     no      no    no
#                      FN7Dad.Mouth.TP2            no     no      no    no
#                      FN7Dad.Mouth.TP1            no     no      no    no
# FN6Child.2.Nasal.TP2 FN9Child.1.Stool.TP1        no     no      no    no
#                      FN9Child.2.Nasal.TP2       yes     no      no    no
#                      FN6Child.2.Stool.TP2        no    yes      no    no
#                      FN7Dad.Mouth.TP3            no     no      no    no
#                      FN7Dad.Mouth.TP2            no     no      no    no
#                      FN7Dad.Mouth.TP1            no     no      no    no
# FN9Child.1.Stool.TP1 FN9Child.2.Nasal.TP2        no     no     yes    no
#                      FN6Child.2.Stool.TP2       yes     no      no    no
#                      FN7Dad.Mouth.TP3            no     no      no    no
#                      FN7Dad.Mouth.TP2            no     no      no    no
#                      FN7Dad.Mouth.TP1            no     no      no    no
# FN9Child.2.Nasal.TP2 FN6Child.2.Stool.TP2        no     no      no    no
#                      FN7Dad.Mouth.TP3            no     no      no    no
#                      FN7Dad.Mouth.TP2            no     no      no    no
#                      FN7Dad.Mouth.TP1            no     no      no    no
# FN6Child.2.Stool.TP2 FN7Dad.Mouth.TP3            no     no      no    no
#                      FN7Dad.Mouth.TP2            no     no      no    no
#                      FN7Dad.Mouth.TP1            no     no      no    no
# FN7Dad.Mouth.TP3     FN7Dad.Mouth.TP2           yes    yes      no    no
#                      FN7Dad.Mouth.TP1           yes    yes      no    no
# FN7Dad.Mouth.TP2     FN7Dad.Mouth.TP1           yes    yes      no    no
#
# [31878 rows x 7 columns]

# %%
for i, row in stack_df.iterrows():
    if row['Family'] == 'yes' and row['Child'] == 'yes':
        stack_df.ix[i,'Relationship'] = 'child'
    elif row['Family'] == 'yes' and row['Sibling'] == 'yes':
        stack_df.ix[i,'Relationship'] = 'sibling'
    elif row['Family'] == 'yes' and row['Person'] == 'yes':
        stack_df.ix[i,'Relationship'] = 'self'
    elif row['Family'] == 'yes':
        stack_df.ix[i,'Relationship'] = 'spouse'
    else:
        stack_df.ix[i,'Relationship'] = 'not'

# %%
#stack_df.head()

# %%
#stack_df.Relationship.unique()

# %%
stack_df['Adopt_Status'].replace('no','not', inplace = True)

# %%
stack_df['Relationship_Adopt'] = stack_df['Relationship'] + '_' + stack_df['Adopt_Status']

# %%
stack_df.drop('Family', axis=1, inplace=True)
stack_df.drop('Person', axis=1, inplace=True)
stack_df.drop('Adopt_Status', axis=1, inplace=True)
stack_df.drop('Sibling', axis=1, inplace=True)
stack_df.drop('Child', axis=1, inplace=True)
stack_df.drop('Relationship', axis=1, inplace=True)

# %%
for i, row in stack_df.iterrows():
    if i[0][:3] == i[1][:3]:
        stack_df.ix[i,'Family_Number_'] = i[0][2]
    else:
        stack_df.ix[i,'Family_Number_'] = '0'

# %%
#stack_df
# Out:
#                                                dist Body_Site  \
# FN4Dad.Mouth.TP2     FN4Dad.Mouth.TP3      0.314122       yes
#                      FN4Dad.Mouth.TP1      0.336239       yes
#                      FN8Dad.Nasal.TP2      0.762721        no
#                      FN8Dad.Nasal.TP3      0.648425        no
#                      FN8Dad.Nasal.TP1      0.820690        no
#                      FN7Child.3.Stool.TP3  0.821582        no
#                      FN7Child.3.Stool.TP2  0.757324        no
#                      FN7Child.3.Stool.TP1  0.757895        no
#                      FN1Child.2.Mouth.TP3  0.570471       yes
#                      FN6Dad.Mouth.TP1      0.286093       yes
#                      FN6Dad.Mouth.TP2      0.205140       yes
#                      FN6Dad.Mouth.TP3      0.208061       yes
#                      FN6Child.3.nasal.TP1  0.654997        no
#                      FN6Child.3.nasal.TP2  0.738669        no
#                      FN3Mom.Nasal.T2       0.661118        no
#                      FN1Mom.Mouth.TP3      0.444215       yes
#                      FN8Child.1.Nasal.TP2  0.528264        no
#                      FN8Dad.Mouth.TP3      0.789817       yes
#                      FN8Child.1.Nasal.TP3  0.719277        no
#                      FN1Child.2.Mouth.TP1  0.703049       yes
#                      FN8Mom.Nasal.TP1      0.813796        no
#                      FN3Mom.Nasal.TP3      0.666133        no
#                      FN8Mom.Nasal.TP3      0.854962        no
#                      FN9Child.1.Mouth.TP3  0.544469       yes
#                      FN9Child.1.Mouth.TP2  0.401080       yes
#                      FN9Child.1.Mouth.TP1  0.512538       yes
#                      FN4Dad.Nasal.TP2      0.826069        no
#                      FN4Dad.Nasal.TP3      0.596023        no
#                      FN4Dad.Nasal.TP1      0.517576        no
#                      FN1Child.2.Nasal.TP2  0.659635        no
# ...                                             ...       ...
# FN6Child.2.Nasal.TP1 FN7Dad.Mouth.TP2      0.554391        no
#                      FN7Dad.Mouth.TP1      0.768364        no
# FN6Child.2.Nasal.TP3 FN6Child.2.Nasal.TP2  0.537077       yes
#                      FN9Child.1.Stool.TP1  0.827523        no
#                      FN9Child.2.Nasal.TP2  0.348061       yes
#                      FN6Child.2.Stool.TP2  0.919074        no
#                      FN7Dad.Mouth.TP3      0.579621        no
#                      FN7Dad.Mouth.TP2      0.349336        no
#                      FN7Dad.Mouth.TP1      0.706582        no
# FN6Child.2.Nasal.TP2 FN9Child.1.Stool.TP1  0.791440        no
#                      FN9Child.2.Nasal.TP2  0.450693       yes
#                      FN6Child.2.Stool.TP2  0.926015        no
#                      FN7Dad.Mouth.TP3      0.771602        no
#                      FN7Dad.Mouth.TP2      0.677197        no
#                      FN7Dad.Mouth.TP1      0.756455        no
# FN9Child.1.Stool.TP1 FN9Child.2.Nasal.TP2  0.818389        no
#                      FN6Child.2.Stool.TP2  0.496134       yes
#                      FN7Dad.Mouth.TP3      0.671444        no
#                      FN7Dad.Mouth.TP2      0.831255        no
#                      FN7Dad.Mouth.TP1      0.667152        no
# FN9Child.2.Nasal.TP2 FN6Child.2.Stool.TP2  0.934217        no
#                      FN7Dad.Mouth.TP3      0.713248        no
#                      FN7Dad.Mouth.TP2      0.520316        no
#                      FN7Dad.Mouth.TP1      0.710723        no
# FN6Child.2.Stool.TP2 FN7Dad.Mouth.TP3      0.691570        no
#                      FN7Dad.Mouth.TP2      0.891752        no
#                      FN7Dad.Mouth.TP1      0.708750        no
# FN7Dad.Mouth.TP3     FN7Dad.Mouth.TP2      0.413509       yes
#                      FN7Dad.Mouth.TP1      0.244596       yes
# FN7Dad.Mouth.TP2     FN7Dad.Mouth.TP1      0.513578       yes
#
#                                           Relationship_Adopt Family_Number_
# FN4Dad.Mouth.TP2     FN4Dad.Mouth.TP3               self_not              4
#                      FN4Dad.Mouth.TP1               self_not              4
#                      FN8Dad.Nasal.TP2                not_not              0
#                      FN8Dad.Nasal.TP3                not_not              0
#                      FN8Dad.Nasal.TP1                not_not              0
#                      FN7Child.3.Stool.TP3            not_not              0
#                      FN7Child.3.Stool.TP2            not_not              0
#                      FN7Child.3.Stool.TP1            not_not              0
#                      FN1Child.2.Mouth.TP3            not_not              0
#                      FN6Dad.Mouth.TP1                not_not              0
#                      FN6Dad.Mouth.TP2                not_not              0
#                      FN6Dad.Mouth.TP3                not_not              0
#                      FN6Child.3.nasal.TP1            not_not              0
#                      FN6Child.3.nasal.TP2            not_not              0
#                      FN3Mom.Nasal.T2                 not_not              0
#                      FN1Mom.Mouth.TP3                not_not              0
#                      FN8Child.1.Nasal.TP2            not_not              0
#                      FN8Dad.Mouth.TP3                not_not              0
#                      FN8Child.1.Nasal.TP3            not_not              0
#                      FN1Child.2.Mouth.TP1            not_not              0
#                      FN8Mom.Nasal.TP1                not_not              0
#                      FN3Mom.Nasal.TP3                not_not              0
#                      FN8Mom.Nasal.TP3                not_not              0
#                      FN9Child.1.Mouth.TP3            not_not              0
#                      FN9Child.1.Mouth.TP2            not_not              0
#                      FN9Child.1.Mouth.TP1            not_not              0
#                      FN4Dad.Nasal.TP2               self_not              4
#                      FN4Dad.Nasal.TP3               self_not              4
#                      FN4Dad.Nasal.TP1               self_not              4
#                      FN1Child.2.Nasal.TP2            not_not              0
# ...                                                      ...            ...
# FN6Child.2.Nasal.TP1 FN7Dad.Mouth.TP2                not_not              0
#                      FN7Dad.Mouth.TP1                not_not              0
# FN6Child.2.Nasal.TP3 FN6Child.2.Nasal.TP2           self_not              6
#                      FN9Child.1.Stool.TP1            not_not              0
#                      FN9Child.2.Nasal.TP2            not_not              0
#                      FN6Child.2.Stool.TP2           self_not              6
#                      FN7Dad.Mouth.TP3                not_not              0
#                      FN7Dad.Mouth.TP2                not_not              0
#                      FN7Dad.Mouth.TP1                not_not              0
# FN6Child.2.Nasal.TP2 FN9Child.1.Stool.TP1            not_not              0
#                      FN9Child.2.Nasal.TP2            not_not              0
#                      FN6Child.2.Stool.TP2           self_not              6
#                      FN7Dad.Mouth.TP3                not_not              0
#                      FN7Dad.Mouth.TP2                not_not              0
#                      FN7Dad.Mouth.TP1                not_not              0
# FN9Child.1.Stool.TP1 FN9Child.2.Nasal.TP2        sibling_not              9
#                      FN6Child.2.Stool.TP2            not_not              0
#                      FN7Dad.Mouth.TP3                not_not              0
#                      FN7Dad.Mouth.TP2                not_not              0
#                      FN7Dad.Mouth.TP1                not_not              0
# FN9Child.2.Nasal.TP2 FN6Child.2.Stool.TP2            not_not              0
#                      FN7Dad.Mouth.TP3                not_not              0
#                      FN7Dad.Mouth.TP2                not_not              0
#                      FN7Dad.Mouth.TP1                not_not              0
# FN6Child.2.Stool.TP2 FN7Dad.Mouth.TP3                not_not              0
#                      FN7Dad.Mouth.TP2                not_not              0
#                      FN7Dad.Mouth.TP1                not_not              0
# FN7Dad.Mouth.TP3     FN7Dad.Mouth.TP2               self_not              7
#                      FN7Dad.Mouth.TP1               self_not              7
# FN7Dad.Mouth.TP2     FN7Dad.Mouth.TP1               self_not              7
#
# [31878 rows x 4 columns]

# %%
stack_df.to_csv('weighted_filtered_unifrac_table.txt')

# %%
#stack_df.head()

# %%
#stack_df[stack_df['Adopt_Status'] != 'no']

# %%
#erson_df = pd.read_csv("filtered_stool_table_person.csv", sep=',', index_col = ['Person1','Person2'])

# %%
#person_df.head()

# %%
#stack_df.head()

# %%
# for i, row in stack_df.iterrows():
#     print i[0]
#     for j, p_row in person_df.iterrows():
#         print j
#         if i[0] == j[0] and i[0] == j[1] and i[1] == j[1]:
#             stack_df.ix[i, 'Person_Number_'] = person_df.ix[j, 'Person']

# %% [markdown]
# To do
# -----
# 1. Remove duplicates
# 2. Remove 0s
# 3. Potentially be able to add metadata fo second sample ID
# 4. Convert categorical data into integers?
#
# Questions
# ---------
# 1. Does the metada for both IDs need to be present?
# 2. Can we do this with beta diversity metrics. This statistic *only* exists as paired data. Why does this work? (It probably won't) - John
# 3.

# %% [markdown]
# Here I want to be able to combine these two data frames. I think that the best way to do this is going to be with the apply function, however there may be a way to do this with merge, join or concat. can't figure it out though.
